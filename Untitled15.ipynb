# %% [markdown]
# <a href="https://colab.research.google.com/github/Vadigalla-siva/Vadigalla-siva/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Github :")
# Out:
# Hello Github :
